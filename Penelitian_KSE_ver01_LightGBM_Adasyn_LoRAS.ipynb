# %% [markdown]
# ## LIbrary

# %%
pip install pycaret

# %%
pip install Jinja2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install markupsafe==2.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires markupsafe~=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
pip install pyloras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Model Ver.01

# %% [markdown]
# **data preparation**

# %%
from pycaret.classification import *
import pandas as pd
from imblearn.over_sampling import ADASYN
from pyloras import LORAS

# %%
df = pd.read_csv('data_gagal_jantung_kongestif.csv')
df.head(2)
# Out:
#    Umur  Gender  Tipe_angina  Tekanan_darah_istirahat  Kolesterol  \
# 0    63       1            3                      145         233
# 1    37       1            2                      130         250
#
#    Gula_darah_puasa  Hasil_Elektrokardiografi  Denyut_jantung_max  \
# 0                 1                         0                 150
# 1                 0                         1                 187
#
#    Angina_aktivitas  st_depression_ECG  st_slope_ECG  num_major_vessels  \
# 0                 0                2.3             0                  0
# 1                 0                3.5             0                  0
#
#    thalassemia  target
# 0            1       1
# 1            2       1

# %% [markdown]
# **Data Profile**

# %% [markdown]
# **Shuffle Train_Test Dataset**

# %%
#shuffle_df = df.sample(frac=1)

# Define a size for your train set 
#train_size = int(0.7 * len(df))

# Split your dataset 
#train_set = shuffle_df[:train_size]
#test_set = shuffle_df[train_size:]

#train_set.tail(3)
# Out:
#      Umur  Gender  Tipe_angina  Tekanan_darah_istirahat  Kolesterol  \
# 64     58       1            2                      140         211
# 56     48       1            0                      122         222
# 254    59       1            3                      160         273
#
#      Gula_darah_puasa  Hasil_Elektrokardiografi  Denyut_jantung_max  \
# 64                  1                         0                 165
# 56                  0                         0                 186
# 254                 0                         0                 125
#
#      Angina_aktivitas  st_depression_ECG  st_slope_ECG  num_major_vessels  \
# 64                  0                0.0             2                  0
# 56                  0                0.0             2                  0
# 254                 0                0.0             2                  0
#
#      thalassemia  target
# 64             2       1
# 56             2       1
# 254            2       0

# %%
print ('train_shape = ', df.shape)
print ('test_shape = ', df.shape)
print ('train_unique_values_label')
print (df.target.value_counts())
print ('test_unique_values_label')
print (df.target.value_counts())
# Out:
# train_shape =  (444, 14)
# test_shape =  (444, 14)
# train_unique_values_label
# 1    306
# 0    138
# Name: target, dtype: int64
# test_unique_values_label
# 1    306
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# # **Eksperimen Adasyn + Light GBM**

# %% [markdown]
# ## **Baseline**

# %% [markdown]
# ### Baseline_Model_utama : **Non - Processing + LightGBM + 10 - Fold**

# %%
#setup baseline model
baseline_model01 = setup(data = df, target = 'target')
# Out:
#                                Description             Value
# 0                               session_id              1774
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 29)
# 12                    Transformed Test Set         (134, 29)
# 13                      Shuffle Train-Test              True
# ...

# %%
baseline_model_utama = create_model('lightgbm', fold = 10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8710  0.9394  0.9091  0.9091  0.9091  0.6869  0.6869
# 1       0.8065  0.8838  0.9091  0.8333  0.8696  0.4973  0.5044
# 2       0.8387  0.9192  0.9091  0.8696  0.8889  0.5953  0.5973
# 3       0.9032  0.9899  1.0000  0.8800  0.9362  0.7395  0.7659
# 4       0.8710  0.9444  0.9091  0.9091  0.9091  0.6869  0.6869
# 5       0.7742  0.8384  0.8636  0.8261  0.8444  0.4334  0.4348
# 6       0.8065  0.8687  0.8636  0.8636  0.8636  0.5303  0.5303
# 7       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8       0.9355  0.9848  0.9545  0.9545  0.9545  0.8434  0.8434
# 9       0.8065  0.9952  1.0000  0.7778  0.8750  0.4746  0.5578
# Mean    0.8613  0.9364  0.9318  0.8823  0.9050  0.6488  0.6608
# Std     0.0662  0.0548  0.0508  0.0612  0.0450  0.1700  0.1637

# %%
pred_hold_baseline_utama = predict_model(baseline_model_utama);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.     F1  \
# 0  Light Gradient Boosting Machine    0.8731  0.9318  0.9195  0.8889  0.904
#
#     Kappa     MCC
# 0  0.7173  0.7182

# %% [markdown]
# ### Baseline_Model01 : **Non - Processing + adasyn + LightGBM + 10 - Fold**

# %%
setup_baseline_model_adasyn = setup(data = df, target = 'target', fix_imbalance = True, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              8029
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 29)
# 12                    Transformed Test Set         (134, 29)
# 13                      Shuffle Train-Test              True
# ...

# %%
baseline_model_adasyn = create_model ('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7419  0.8545  0.8000  0.8000  0.8000  0.4364  0.4364
# 1       0.8387  0.8909  0.8500  0.8947  0.8718  0.6548  0.6564
# 2       0.7419  0.8857  0.8571  0.7826  0.8182  0.3769  0.3815
# 3       0.8710  0.9476  0.8571  0.9474  0.9000  0.7195  0.7266
# 4       0.7419  0.9333  0.7143  0.8824  0.7895  0.4655  0.4831
# 5       0.8387  0.9381  0.8571  0.9000  0.8780  0.6404  0.6420
# 6       0.8710  0.9333  1.0000  0.8400  0.9130  0.6702  0.7099
# 7       0.8065  0.9714  0.9524  0.8000  0.8696  0.5053  0.5353
# 8       0.9032  0.9524  0.9048  0.9500  0.9268  0.7842  0.7863
# 9       0.8710  0.9333  0.9048  0.9048  0.9048  0.7048  0.7048
# Mean    0.8226  0.9241  0.8698  0.8702  0.8672  0.5958  0.6062
# Std     0.0582  0.0338  0.0749  0.0580  0.0461  0.1312  0.1307

# %%
#hasil baseline adasyn
pred_hold_adasyn_model = predict_model(baseline_model_adasyn);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.     F1  \
# 0  Light Gradient Boosting Machine    0.8731  0.9515  0.8878  0.9355  0.911
#
#     Kappa     MCC
# 0  0.6907  0.6936

# %% [markdown]
# ### Baseline Model02 : **non-processing + LightGBM + boosting/bagging + 5 - Fold**

# %%
baseline_model03 = setup(data = df, target = 'target', fold = 5)
# Out:
#                                Description             Value
# 0                               session_id              4982
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 29)
# 12                    Transformed Test Set         (134, 29)
# 13                      Shuffle Train-Test              True
# ...

# %%
baseline_model_03 = create_model('lightgbm', fold = 5)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8065  0.8960  0.8140  0.8974  0.8537  0.5699  0.5759
# 1       0.8387  0.8923  0.8837  0.8837  0.8837  0.6206  0.6206
# 2       0.8548  0.9266  0.9070  0.8864  0.8966  0.6534  0.6539
# 3       0.8548  0.9331  0.8864  0.9070  0.8966  0.6534  0.6539
# 4       0.8710  0.9419  0.9545  0.8750  0.9130  0.6649  0.6744
# Mean    0.8452  0.9180  0.8891  0.8899  0.8887  0.6324  0.6357
# Std     0.0219  0.0201  0.0454  0.0111  0.0198  0.0346  0.0345

# %%
op_baseline_model_03 = ensemble_model(baseline_model_03, method = 'Boosting', fold = 5, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8065  0.8874  0.8140  0.8974  0.8537  0.5699  0.5759
# 1       0.8387  0.8837  0.8837  0.8837  0.8837  0.6206  0.6206
# 2       0.8710  0.9253  0.9070  0.9070  0.9070  0.6965  0.6965
# 3       0.8548  0.9318  0.8864  0.9070  0.8966  0.6534  0.6539
# 4       0.8710  0.9432  0.9545  0.8750  0.9130  0.6649  0.6744
# Mean    0.8484  0.9143  0.8891  0.8940  0.8908  0.6410  0.6442
# Std     0.0241  0.0242  0.0454  0.0128  0.0211  0.0430  0.0423

# %%
op_baseline_model_bag = ensemble_model(baseline_model_03, fold = 5, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8548  0.9033  0.9070  0.8864  0.8966  0.6534  0.6539
# 1       0.8548  0.9119  0.9070  0.8864  0.8966  0.6534  0.6539
# 2       0.8871  0.9315  0.9535  0.8913  0.9213  0.7222  0.7273
# 3       0.9194  0.9545  0.9318  0.9535  0.9425  0.8075  0.8081
# 4       0.8548  0.9432  0.9545  0.8571  0.9032  0.6162  0.6307
# Mean    0.8742  0.9289  0.9308  0.8949  0.9120  0.6905  0.6948
# Std     0.0258  0.0190  0.0210  0.0317  0.0177  0.0677  0.0653

# %%
# hasil baseline_boosting
pred_hold_baseline_boosting = predict_model(op_baseline_model_03);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8507  0.9416  0.8989  0.8791  0.8889
#
#     Kappa     MCC
# 0  0.6617  0.6621

# %%
# hasil baseline_bagging
pred_hold_bagg = predict_model(op_baseline_model_bag);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8433  0.9441  0.8876  0.8778  0.8827
#
#     Kappa     MCC
# 0  0.6467  0.6468

# %% [markdown]
# ## **Boosting**

# %% [markdown]
# ### Learning 01 : **Variable Selection + Normalization + adasyn + LightGBM + 10 - Fold + Boosting**

# %% [markdown]
# **Model Setting Ver.01**

# %%
s1 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'], 
           normalize = True, fix_imbalance = True, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              7083
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
# create models
create_model01 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8710  0.9747  0.8636  0.9500  0.9048  0.7062  0.7139
# 1       0.8387  0.8990  0.9545  0.8400  0.8936  0.5658  0.5861
# 2       0.8710  0.8990  0.8636  0.9500  0.9048  0.7062  0.7139
# 3       0.8387  0.9495  0.8636  0.9048  0.8837  0.6210  0.6228
# 4       0.8065  0.9343  0.8636  0.8636  0.8636  0.5303  0.5303
# 5       0.8710  0.9798  0.9091  0.9091  0.9091  0.6869  0.6869
# 6       0.7419  0.9000  0.8095  0.8095  0.8095  0.4095  0.4095
# 7       0.8065  0.8667  0.8571  0.8571  0.8571  0.5571  0.5571
# 8       0.8065  0.9619  0.9524  0.8000  0.8696  0.5053  0.5353
# 9       0.8710  0.9381  0.8571  0.9474  0.9000  0.7195  0.7266
# Mean    0.8323  0.9303  0.8794  0.8832  0.8796  0.6008  0.6082
# Std     0.0403  0.0358  0.0433  0.0543  0.0292  0.0989  0.0984

# %%
# Optimize Model 01
op_model01 = ensemble_model(create_model01, method = 'Boosting', n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8710  0.9747  0.8636  0.9500  0.9048  0.7062  0.7139
# 1       0.8710  0.9545  1.0000  0.8462  0.9167  0.6395  0.6856
# 2       0.8387  0.9091  0.8636  0.9048  0.8837  0.6210  0.6228
# 3       0.8710  0.9495  0.9091  0.9091  0.9091  0.6869  0.6869
# 4       0.8387  0.9394  0.9091  0.8696  0.8889  0.5953  0.5973
# 5       0.8710  0.9747  0.9091  0.9091  0.9091  0.6869  0.6869
# 6       0.7419  0.8905  0.8095  0.8095  0.8095  0.4095  0.4095
# 7       0.8065  0.8714  0.8571  0.8571  0.8571  0.5571  0.5571
# 8       0.8065  0.9667  0.9524  0.8000  0.8696  0.5053  0.5353
# 9       0.8710  0.9190  0.8571  0.9474  0.9000  0.7195  0.7266
# Mean    0.8387  0.9350  0.8931  0.8803  0.8848  0.6127  0.6222
# Std     0.0408  0.0342  0.0520  0.0499  0.0308  0.0939  0.0945

# %%
# testing hold_out score
pred_hold01 = predict_model(op_model01);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.     F1  \
# 0  Light Gradient Boosting Machine    0.8881  0.9318  0.9333  0.9032  0.918
#
#     Kappa     MCC
# 0  0.7417  0.7427

# %% [markdown]
# ### Learning 02 : **Variable Selection + Normalization + adasyn + LightGBM + 7 - Fold + Boosting**

# %% [markdown]
# **Model Setting Ver.02**

# %%
#setup model 02
s2 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fold = 7, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              5736
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
#create model 02
model02 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8222  0.8822  0.9062  0.8529  0.8788  0.5466  0.5501
# 1       0.8444  0.9423  0.9375  0.8571  0.8955  0.5935  0.6028
# 2       0.8636  0.9132  0.9355  0.8788  0.9062  0.6571  0.6615
# 3       0.8636  0.9355  0.9355  0.8788  0.9062  0.6571  0.6615
# 4       0.9091  0.9404  0.9355  0.9355  0.9355  0.7816  0.7816
# 5       0.8864  0.9628  0.9032  0.9333  0.9180  0.7330  0.7341
# 6       0.9091  0.9777  0.9677  0.9091  0.9375  0.7714  0.7765
# Mean    0.8712  0.9363  0.9316  0.8922  0.9111  0.6772  0.6812
# Std     0.0301  0.0291  0.0201  0.0316  0.0195  0.0826  0.0811

# %%
# optimize model 02
op_model02 = ensemble_model(model02, method = 'Boosting', n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8222  0.8966  0.9062  0.8529  0.8788  0.5466  0.5501
# 1       0.8667  0.9375  0.9375  0.8824  0.9091  0.6599  0.6642
# 2       0.8182  0.9057  0.8710  0.8710  0.8710  0.5633  0.5633
# 3       0.8636  0.9504  0.9677  0.8571  0.9091  0.6403  0.6596
# 4       0.8636  0.9479  0.9032  0.9032  0.9032  0.6725  0.6725
# 5       0.8864  0.9628  0.9032  0.9333  0.9180  0.7330  0.7341
# 6       0.9091  0.9727  0.9677  0.9091  0.9375  0.7714  0.7765
# Mean    0.8614  0.9391  0.9224  0.8870  0.9038  0.6553  0.6600
# Std     0.0301  0.0262  0.0338  0.0273  0.0210  0.0759  0.0762

# %%
# Result Model 02
pred_hold02 = predict_model(op_model02);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8582  0.9435  0.8966  0.8864  0.8914
#
#     Kappa     MCC
# 0  0.6871  0.6872

# %% [markdown]
# ### Learning 03 : **Variable Selection + Normalization + adasyn + LightGBM + 5 - Fold + Boosting**

# %% [markdown]
# **Model Setting Ver.03**

# %%
#setup model 03
s3 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fold = 5, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              7687
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
# Create Model 03
model03 = create_model('lightgbm', fold = 5)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9032  0.9786  0.9286  0.9286  0.9286  0.7786  0.7786
# 1       0.8871  0.9655  0.9048  0.9268  0.9157  0.7450  0.7455
# 2       0.9032  0.9512  0.9524  0.9091  0.9302  0.7726  0.7748
# 3       0.8710  0.9535  0.9070  0.9070  0.9070  0.6965  0.6965
# 4       0.8548  0.9045  0.8837  0.9048  0.8941  0.6634  0.6639
# Mean    0.8839  0.9507  0.9153  0.9152  0.9151  0.7312  0.7319
# Std     0.0188  0.0250  0.0234  0.0103  0.0135  0.0446  0.0449

# %%
# optimize model 03
op_model03 = ensemble_model(model03, method = 'Boosting', fold = 5, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9355  0.9690  0.9286  0.9750  0.9512  0.8561  0.8584
# 1       0.8710  0.9702  0.9048  0.9048  0.9048  0.7048  0.7048
# 2       0.8871  0.9536  0.9524  0.8889  0.9195  0.7311  0.7360
# 3       0.8710  0.9559  0.9070  0.9070  0.9070  0.6965  0.6965
# 4       0.8387  0.9119  0.8605  0.9024  0.8810  0.6314  0.6331
# Mean    0.8806  0.9521  0.9106  0.9156  0.9127  0.7240  0.7257
# Std     0.0316  0.0212  0.0304  0.0304  0.0230  0.0738  0.0743

# %%
# Result Model 03
pred_hold03 = predict_model(op_model03);
# Out:
#                              Model  Accuracy     AUC  Recall  Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8358  0.9104  0.8936  0.875  0.8842
#
#     Kappa     MCC
# 0  0.6023  0.6027

# %% [markdown]
# ## **Bagging**

# %% [markdown]
# ### Learning 04 : **Variable Selection + Normalization + adasyn + LightGBM + 10 - Fold + Bagging**

# %% [markdown]
# **Model Setting Ver.04**

# %%
#setup model 04
s4 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              2047
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
# Create Model 04
model04 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9677  0.9343  1.0000  0.9565  0.9778  0.9191  0.9221
# 1       0.9355  0.9899  0.9545  0.9545  0.9545  0.8434  0.8434
# 2       0.6774  0.8939  0.6364  0.8750  0.7368  0.3460  0.3762
# 3       0.8065  0.9192  0.7727  0.9444  0.8500  0.5848  0.6086
# 4       0.8710  0.9899  1.0000  0.8462  0.9167  0.6395  0.6856
# 5       0.8710  0.9293  0.9091  0.9091  0.9091  0.6869  0.6869
# 6       0.8065  0.8283  0.9545  0.8077  0.8750  0.4593  0.4924
# 7       0.8387  0.9293  0.9091  0.8696  0.8889  0.5953  0.5973
# 8       0.8387  0.9190  0.8571  0.9000  0.8780  0.6404  0.6420
# 9       0.8710  0.9333  0.9524  0.8696  0.9091  0.6884  0.6970
# Mean    0.8484  0.9267  0.8946  0.8933  0.8896  0.6403  0.6551
# Std     0.0750  0.0436  0.1078  0.0466  0.0622  0.1575  0.1485

# %%
# optimize model 04
op_model04 = ensemble_model(model04, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9677  0.9394  1.0000  0.9565  0.9778  0.9191  0.9221
# 1       0.9677  0.9949  0.9545  1.0000  0.9767  0.9242  0.9269
# 2       0.7419  0.8687  0.6818  0.9375  0.7895  0.4768  0.5184
# 3       0.8387  0.9293  0.8182  0.9474  0.8780  0.6437  0.6589
# 4       0.9355  0.9798  1.0000  0.9167  0.9565  0.8324  0.8444
# 5       0.8387  0.9394  0.8636  0.9048  0.8837  0.6210  0.6228
# 6       0.8387  0.8687  0.9545  0.8400  0.8936  0.5658  0.5861
# 7       0.8710  0.9545  0.9091  0.9091  0.9091  0.6869  0.6869
# 8       0.8387  0.9333  0.8571  0.9000  0.8780  0.6404  0.6420
# 9       0.9032  0.9333  0.9524  0.9091  0.9302  0.7726  0.7748
# Mean    0.8742  0.9341  0.8991  0.9221  0.9073  0.7083  0.7183
# Std     0.0668  0.0385  0.0929  0.0400  0.0539  0.1419  0.1345

# %%
# Result Model 03
pred_hold04 = predict_model(op_model04);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8358  0.9311  0.8636  0.8837  0.8736
#
#     Kappa   MCC
# 0  0.6396  0.64

# %% [markdown]
# ### Learning 05 : **Variable Selection + Normalization + adasyn + LightGBM + 7 - Fold + Bagging**

# %% [markdown]
# **Model Setting Ver.05**

# %%
#setup model 05
s5 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fold = 7, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              7856
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
# Create Model 05
model05 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8444  0.9207  0.9062  0.8788  0.8923  0.6125  0.6135
# 1       0.7778  0.9167  0.8182  0.8710  0.8438  0.4604  0.4631
# 2       0.8636  0.9219  0.9062  0.9062  0.9062  0.6562  0.6562
# 3       0.8182  0.8464  0.8125  0.9286  0.8667  0.5849  0.5979
# 4       0.8409  0.9271  0.9375  0.8571  0.8955  0.5650  0.5751
# 5       0.8636  0.9375  0.8750  0.9333  0.9032  0.6733  0.6773
# 6       0.9091  0.9740  0.9062  0.9667  0.9355  0.7822  0.7869
# Mean    0.8454  0.9206  0.8803  0.9060  0.8919  0.6192  0.6243
# Std     0.0379  0.0353  0.0444  0.0364  0.0273  0.0928  0.0922

# %%
# optimize model 05
op_model05 = ensemble_model(model05, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8889  0.9495  0.9062  0.9355  0.9206  0.7356  0.7366
# 1       0.8000  0.9040  0.8182  0.9000  0.8571  0.5263  0.5330
# 2       0.8864  0.9453  0.9062  0.9355  0.9206  0.7208  0.7219
# 3       0.8182  0.8854  0.8125  0.9286  0.8667  0.5849  0.5979
# 4       0.8409  0.9401  0.9375  0.8571  0.8955  0.5650  0.5751
# 5       0.8636  0.9323  0.9062  0.9062  0.9062  0.6562  0.6562
# 6       0.9091  0.9896  0.8750  1.0000  0.9333  0.7925  0.8101
# Mean    0.8582  0.9352  0.8803  0.9233  0.9000  0.6545  0.6616
# Std     0.0371  0.0310  0.0444  0.0404  0.0266  0.0920  0.0921

# %%
# Result Model 04
pred_hold05 = predict_model(op_model05);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8582  0.9511  0.9136  0.8605  0.8862
#
#     Kappa     MCC
# 0  0.6986  0.7008

# %% [markdown]
# ### Learning 06 : **Variable Selection + Normalization + adasyn + LightGBM + 5 - Fold + Bagging**

# %% [markdown]
# **Model Setting Ver.06**

# %%
#setup model 06
s6 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fold = 5, fix_imbalance_method = ADASYN())
# Out:
#                                Description             Value
# 0                               session_id              5389
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
# Create Model 06
model06 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9194  0.9657  0.9535  0.9318  0.9425  0.8075  0.8081
# 1       0.8387  0.9168  0.9070  0.8667  0.8864  0.6091  0.6109
# 2       0.9355  0.9767  0.9767  0.9333  0.9545  0.8436  0.8462
# 3       0.8065  0.9036  0.8810  0.8409  0.8605  0.5452  0.5468
# 4       0.9194  0.9774  0.9048  0.9744  0.9383  0.8225  0.8272
# Mean    0.8839  0.9480  0.9246  0.9094  0.9164  0.7256  0.7278
# Std     0.0514  0.0315  0.0351  0.0486  0.0365  0.1234  0.1239

# %%
# optimize model 06
op_model06 = ensemble_model(model06, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8710  0.9596  0.8605  0.9487  0.9024  0.7133  0.7207
# 1       0.8548  0.9412  0.9070  0.8864  0.8966  0.6534  0.6539
# 2       0.8871  0.9718  0.9070  0.9286  0.9176  0.7382  0.7388
# 3       0.8226  0.9155  0.8810  0.8605  0.8706  0.5887  0.5891
# 4       0.9194  0.9845  0.9048  0.9744  0.9383  0.8225  0.8272
# Mean    0.8710  0.9545  0.8920  0.9197  0.9051  0.7032  0.7059
# Std     0.0323  0.0242  0.0186  0.0413  0.0225  0.0789  0.0804

# %%
# Result Model 06
pred_hold06 = predict_model(op_model06);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8806  0.9357  0.9247  0.9053  0.9149
#
#    Kappa     MCC
# 0  0.715  0.7154

# %%
print(op_model06_estimator)
# Out:
# BaggingClassifier(base_estimator=LGBMClassifier(boosting_type='gbdt',
#                                                 class_weight=None,
#                                                 colsample_bytree=1.0,
#                                                 importance_type='split',
#                                                 learning_rate=0.1, max_depth=-1,
#                                                 min_child_samples=20,
#                                                 min_child_weight=0.001,
#                                                 min_split_gain=0.0,
#                                                 n_estimators=100, n_jobs=-1,
#                                                 num_leaves=31, objective=None,
#                                                 random_state=5919,
#                                                 reg_alpha=0.0, reg_lambda=0.0,
#                                                 silent='warn', subsample=1.0,
# ...

# %% [markdown]
# # **Eksperimen LoRAS + LightGBM**

# %% [markdown]
# ## **Baseline**

# %% [markdown]
# ### Baseline_Loras01 : **Non - Processing + LoRAS + LightGBM + 10 - Fold**

# %%
test_loras = setup(data = df, target = 'target', fix_imbalance = True, fix_imbalance_method = LORAS())
# Out:
#                                Description             Value
# 0                               session_id              4859
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 28)
# 12                    Transformed Test Set         (134, 28)
# 13                      Shuffle Train-Test              True
# ...

# %%
help(get_config)
# Out:
# Help on function get_config in module pycaret.classification:
#
# get_config(variable: str)
#     This function retrieves the global variables created when initializing the
#     ``setup`` function. Following variables are accessible:
#
#     - X: Transformed dataset (X)
#     - y: Transformed dataset (y)
#     - X_train: Transformed train dataset (X)
#     - X_test: Transformed test/holdout dataset (X)
#     - y_train: Transformed train dataset (y)
#     - y_test: Transformed test/holdout dataset (y)
#     - seed: random state set through session_id
#     - prep_pipe: Transformation pipeline
#     - fold_shuffle_param: shuffle parameter used in Kfolds
#     - n_jobs_param: n_jobs parameter used in model training
#     - html_param: html_param configured through setup
#     - create_model_container: results grid storage container
#     - master_model_container: model storage container
#     - display_container: results display container
#     - exp_name_log: Name of experiment
# ...

# %%
X_train = get_config('X_train') 
y_train = get_config('y_train')
X_test = get_config('X_test')
y_test = get_config('y_test')
X = get_config('X')
y = get_config('y')
imbalanced_method_param = get_config('fix_imbalance_method_param')

# %%
print(imbalanced_method_param)
print(y_train.value_counts())
print(y.value_counts())
# Out:
# LORAS(manifold_learner=None, manifold_learner_params=None, n_affine=None,
#       n_jobs=None, n_neighbors=None, n_shadow=None, random_state=None,
#       sampling_strategy='auto', std=0.005)
# 1    213
# 0     97
# Name: target, dtype: int64
# 1    306
# 0    138
# Name: target, dtype: int64

# %%
model_loras01 = create_model('lightgbm', fold = 10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7742  0.8939  0.8182  0.8571  0.8372  0.4694  0.4708
# 1       0.8387  0.9697  0.8182  0.9474  0.8780  0.6437  0.6589
# 2       0.7742  0.8535  0.8182  0.8571  0.8372  0.4694  0.4708
# 3       0.8387  0.9524  0.9048  0.8636  0.8837  0.6210  0.6228
# 4       0.8710  0.9524  0.9048  0.9048  0.9048  0.7048  0.7048
# 5       0.7419  0.8429  0.8095  0.8095  0.8095  0.4095  0.4095
# 6       0.9032  0.9619  0.9048  0.9500  0.9268  0.7842  0.7863
# 7       0.9032  0.9190  1.0000  0.8750  0.9333  0.7597  0.7826
# 8       0.8710  0.9048  0.9524  0.8696  0.9091  0.6884  0.6970
# 9       0.8710  0.9571  0.9048  0.9048  0.9048  0.7048  0.7048
# Mean    0.8387  0.9208  0.8835  0.8839  0.8824  0.6255  0.6308
# Std     0.0540  0.0436  0.0620  0.0411  0.0396  0.1247  0.1279

# %%
#hasil baseline_model_loras non processing
pred_hold_Loras01 = predict_model(model_loras01);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.9254  0.9709  0.9462  0.9462  0.9462
#
#     Kappa     MCC
# 0  0.8243  0.8243

# %%
evaluate_model(model_loras01)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## **Boosting**

# %% [markdown]
# ### Loras Learning 01 : **Variable Selection + Normalization + loras + LightGBM + 10 - Fold + Boosting**

# %%
loras_s1 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'], 
           normalize = True, fix_imbalance = True, fix_imbalance_method = LORAS())
# Out:
#                                Description             Value
# 0                               session_id               195
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
loras_model1 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8387  0.9409  0.8000  0.9412  0.8649  0.6681  0.6817
# 1       0.8387  0.9524  0.9048  0.8636  0.8837  0.6210  0.6228
# 2       0.8387  0.9333  0.8571  0.9000  0.8780  0.6404  0.6420
# 3       0.8710  0.9714  0.8571  0.9474  0.9000  0.7195  0.7266
# 4       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 5       0.7742  0.8286  0.8571  0.8182  0.8372  0.4694  0.4708
# 6       0.8710  0.9190  0.9524  0.8696  0.9091  0.6884  0.6970
# 7       0.7097  0.8095  0.8095  0.7727  0.7907  0.3178  0.3188
# 8       0.8387  0.9476  0.8571  0.9000  0.8780  0.6404  0.6420
# 9       0.8065  0.8857  0.8095  0.8947  0.8500  0.5792  0.5850
# Mean    0.8387  0.9189  0.8705  0.8907  0.8792  0.6344  0.6387
# Std     0.0707  0.0576  0.0615  0.0618  0.0516  0.1660  0.1665

# %%
op_loras_model1 = ensemble_model(loras_model1, method = 'Boosting', n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8710  0.9273  0.8000  1.0000  0.8889  0.7395  0.7659
# 1       0.8065  0.9381  0.9048  0.8261  0.8636  0.5327  0.5392
# 2       0.8387  0.9429  0.8571  0.9000  0.8780  0.6404  0.6420
# 3       0.8387  0.9619  0.8571  0.9000  0.8780  0.6404  0.6420
# 4       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 5       0.8065  0.8333  0.9048  0.8261  0.8636  0.5327  0.5392
# 6       0.8710  0.9429  1.0000  0.8400  0.9130  0.6702  0.7099
# 7       0.7419  0.8190  0.8571  0.7826  0.8182  0.3769  0.3815
# 8       0.8387  0.9571  0.9048  0.8636  0.8837  0.6210  0.6228
# 9       0.7742  0.9048  0.8095  0.8500  0.8293  0.4965  0.4978
# Mean    0.8387  0.9227  0.8895  0.8788  0.8816  0.6250  0.6341
# Std     0.0661  0.0537  0.0653  0.0690  0.0474  0.1586  0.1605

# %%
pred_loras_model1 = predict_model(op_loras_model1);
# Out:
#                              Model  Accuracy    AUC  Recall  Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8955  0.959  0.8969  0.956  0.9255
#
#     Kappa     MCC
# 0  0.7511  0.7554

# %% [markdown]
# ### loras Learning 02 : **Variable Selection + Normalization + loras + LightGBM + 7 - Fold + Boosting**

# %%
loras_s2 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'], 
           normalize = True, fix_imbalance = True, fix_imbalance_method = LORAS(), fold = 7)
# Out:
#                                Description             Value
# 0                               session_id              7371
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
loras_model2 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8889  0.9712  0.9375  0.9091  0.9231  0.7232  0.7244
# 1       0.9333  0.9808  0.9375  0.9677  0.9524  0.8414  0.8425
# 2       0.7500  0.8784  0.8387  0.8125  0.8254  0.3858  0.3864
# 3       0.8409  0.8834  0.8710  0.9000  0.8852  0.6262  0.6271
# 4       0.8636  0.9280  0.9032  0.9032  0.9032  0.6725  0.6725
# 5       0.8182  0.9181  0.9032  0.8485  0.8750  0.5429  0.5464
# 6       0.9545  0.9851  0.9677  0.9677  0.9677  0.8908  0.8908
# Mean    0.8642  0.9350  0.9084  0.9013  0.9046  0.6690  0.6700
# Std     0.0646  0.0416  0.0406  0.0529  0.0449  0.1603  0.1599

# %%
op_loras_model2 = ensemble_model(loras_model2, method = 'Boosting', n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8889  0.9519  0.9375  0.9091  0.9231  0.7232  0.7244
# 1       0.9111  0.9832  0.9688  0.9118  0.9394  0.7733  0.7783
# 2       0.7727  0.8883  0.8387  0.8387  0.8387  0.4541  0.4541
# 3       0.8864  0.8883  0.9355  0.9062  0.9206  0.7208  0.7219
# 4       0.8182  0.9256  0.8710  0.8710  0.8710  0.5633  0.5633
# 5       0.8182  0.8883  0.9032  0.8485  0.8750  0.5429  0.5464
# 6       0.9545  0.9777  0.9677  0.9677  0.9677  0.8908  0.8908
# Mean    0.8643  0.9290  0.9175  0.8933  0.9051  0.6669  0.6685
# Std     0.0586  0.0393  0.0454  0.0410  0.0417  0.1409  0.1411

# %%
pred_loras_model2 = predict_model(op_loras_model2);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8582  0.9181  0.9195  0.8696  0.8939
#
#     Kappa     MCC
# 0  0.6809  0.6833

# %% [markdown]
# ### loras Learning 03 : **Variable Selection + Normalization + loras + LightGBM + 5 - Fold + Boosting**

# %%
loras_s3 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'], 
           normalize = True, fix_imbalance = True, fix_imbalance_method = LORAS(), fold = 5)
# Out:
#                                Description             Value
# 0                               session_id               683
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 25)
# 12                    Transformed Test Set         (134, 25)
# 13                      Shuffle Train-Test              True
# ...

# %%
loras_model3 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9032  0.9524  0.9048  0.9500  0.9268  0.7842  0.7863
# 1       0.9194  0.9670  0.9535  0.9318  0.9425  0.8075  0.8081
# 2       0.8548  0.9131  0.9302  0.8696  0.8989  0.6428  0.6474
# 3       0.8065  0.9155  0.8605  0.8605  0.8605  0.5447  0.5447
# 4       0.8710  0.9180  0.9070  0.9070  0.9070  0.6965  0.6965
# Mean    0.8710  0.9332  0.9112  0.9038  0.9071  0.6951  0.6966
# Std     0.0395  0.0222  0.0309  0.0346  0.0279  0.0958  0.0959

# %%
op_loras_model3 = ensemble_model(loras_model3, method = 'Boosting', n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8710  0.9476  0.9048  0.9048  0.9048  0.7048  0.7048
# 1       0.8710  0.9633  0.9070  0.9070  0.9070  0.6965  0.6965
# 2       0.8387  0.9045  0.9302  0.8511  0.8889  0.5969  0.6048
# 3       0.8226  0.9278  0.8605  0.8810  0.8706  0.5887  0.5891
# 4       0.8548  0.9266  0.8837  0.9048  0.8941  0.6634  0.6639
# Mean    0.8516  0.9340  0.8972  0.8897  0.8931  0.6500  0.6518
# Std     0.0188  0.0200  0.0236  0.0215  0.0131  0.0488  0.0471

# %%
pred_loras_model3 = predict_model(op_loras_model3);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8731  0.9309   0.913  0.9032  0.9081
#
#     Kappa     MCC
# 0  0.7033  0.7034

# %% [markdown]
# ## **Bagging**

# %% [markdown]
# ### Loras Learning 04 : **Variable Selection + Normalization + loras + LightGBM + 10 - Fold + Bagging**

# %%
#setup model 04
loras_s4 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fix_imbalance_method = LORAS())
# Out:
#                                Description             Value
# 0                               session_id               539
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
loras_model4 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8065  0.9048  0.8571  0.8571  0.8571  0.5571  0.5571
# 1       0.9032  0.9238  0.9048  0.9500  0.9268  0.7842  0.7863
# 2       0.8710  0.8857  1.0000  0.8400  0.9130  0.6702  0.7099
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.8387  0.9524  0.8571  0.9000  0.8780  0.6404  0.6420
# 5       0.8710  0.9667  0.9048  0.9048  0.9048  0.7048  0.7048
# 6       0.9032  0.9048  0.9524  0.9091  0.9302  0.7726  0.7748
# 7       0.9355  0.9952  1.0000  0.9130  0.9545  0.8442  0.8547
# 8       0.6774  0.8190  0.7619  0.7619  0.7619  0.2619  0.2619
# 9       0.8710  0.9545  0.9091  0.9091  0.9091  0.6869  0.6869
# Mean    0.8677  0.9307  0.9147  0.8945  0.9036  0.6922  0.6978
# Std     0.0809  0.0521  0.0731  0.0609  0.0601  0.1843  0.1852

# %%
op_loras_model4 = ensemble_model(loras_model4, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7742  0.8571  0.8571  0.8182  0.8372  0.4694  0.4708
# 1       0.9032  0.9333  0.9048  0.9500  0.9268  0.7842  0.7863
# 2       0.8387  0.9095  0.9524  0.8333  0.8889  0.5995  0.6176
# 3       0.9677  0.9952  0.9524  1.0000  0.9756  0.9281  0.9305
# 4       0.8710  0.9476  0.9048  0.9048  0.9048  0.7048  0.7048
# 5       0.9032  0.9905  0.9048  0.9500  0.9268  0.7842  0.7863
# 6       0.9032  0.9095  0.9524  0.9091  0.9302  0.7726  0.7748
# 7       0.9355  0.9905  1.0000  0.9130  0.9545  0.8442  0.8547
# 8       0.6452  0.8190  0.7619  0.7273  0.7442  0.1663  0.1667
# 9       0.8710  0.9495  0.9091  0.9091  0.9091  0.6869  0.6869
# Mean    0.8613  0.9302  0.9100  0.8915  0.8998  0.6740  0.6779
# Std     0.0878  0.0554  0.0619  0.0746  0.0628  0.2083  0.2089

# %%
pred_loras_model4 = predict_model(op_loras_model4);
# Out:
#                              Model  Accuracy    AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8657  0.942  0.9474  0.8738  0.9091
#
#     Kappa     MCC
# 0  0.6535  0.6614

# %% [markdown]
# ### Loras Learning 05 : **Variable Selection + Normalization + loras + LightGBM + 7 - Fold + Bagging**

# %%
#setup model 05
loras_s5 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fix_imbalance_method = LORAS(), fold = 7)
# Out:
#                                Description             Value
# 0                               session_id              7944
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
loras_model5 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8444  0.8966  0.9062  0.8788  0.8923  0.6125  0.6135
# 1       0.8889  0.9255  0.9375  0.9091  0.9231  0.7232  0.7244
# 2       0.7500  0.8307  0.8125  0.8387  0.8254  0.3858  0.3864
# 3       0.9091  0.9583  0.9375  0.9375  0.9375  0.7708  0.7708
# 4       0.9091  0.9427  0.9688  0.9118  0.9394  0.7582  0.7638
# 5       0.8636  0.9256  0.9032  0.9032  0.9032  0.6725  0.6725
# 6       0.9545  0.9926  1.0000  0.9394  0.9688  0.8857  0.8916
# Mean    0.8742  0.9246  0.9237  0.9026  0.9128  0.6870  0.6890
# Std     0.0604  0.0473  0.0552  0.0324  0.0426  0.1461  0.1474

# %%
op_loras_model5 = ensemble_model(loras_model5, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8444  0.9255  0.9062  0.8788  0.8923  0.6125  0.6135
# 1       0.8889  0.9279  0.9062  0.9355  0.9206  0.7356  0.7366
# 2       0.7727  0.8646  0.8438  0.8438  0.8438  0.4271  0.4271
# 3       0.9091  0.9453  0.9375  0.9375  0.9375  0.7708  0.7708
# 4       0.9318  0.9688  1.0000  0.9143  0.9552  0.8136  0.8281
# 5       0.8636  0.9231  0.9032  0.9032  0.9032  0.6725  0.6725
# 6       0.9318  0.9901  1.0000  0.9118  0.9538  0.8245  0.8375
# Mean    0.8775  0.9350  0.9281  0.9035  0.9152  0.6938  0.6980
# Std     0.0525  0.0369  0.0523  0.0306  0.0366  0.1294  0.1333

# %%
pred_loras_model5 = predict_model(op_loras_model5);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8507  0.9371  0.9405  0.8404  0.8876
#
#     Kappa     MCC
# 0  0.6675  0.6769

# %% [markdown]
# ### Loras Learning 06 : **Variable Selection + Normalization + loras + LightGBM + 5 - Fold + Bagging**

# %%
#setup model 06
loras_s6 = setup(data = df, target = 'target', ignore_features = ['Gula_darah_puasa'],
           normalize = True, fix_imbalance = True, fix_imbalance_method = LORAS(), fold = 5)
# Out:
#                                Description             Value
# 0                               session_id              2281
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (444, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (310, 26)
# 12                    Transformed Test Set         (134, 26)
# 13                      Shuffle Train-Test              True
# ...

# %%
loras_model6 = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8387  0.9168  0.9070  0.8667  0.8864  0.6091  0.6109
# 1       0.8871  0.9706  0.9535  0.8913  0.9213  0.7222  0.7273
# 2       0.8871  0.9645  0.9070  0.9286  0.9176  0.7382  0.7388
# 3       0.8871  0.9731  0.9070  0.9286  0.9176  0.7382  0.7388
# 4       0.8226  0.8750  0.9286  0.8298  0.8764  0.5656  0.5770
# Mean    0.8645  0.9400  0.9206  0.8890  0.9039  0.6747  0.6786
# Std     0.0281  0.0385  0.0184  0.0378  0.0187  0.0728  0.0700

# %%
op_loras_model6 = ensemble_model(loras_model6, n_estimators = 50)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8226  0.9278  0.9070  0.8478  0.8764  0.5634  0.5674
# 1       0.9032  0.9682  0.9535  0.9111  0.9318  0.7654  0.7678
# 2       0.9194  0.9804  0.9302  0.9524  0.9412  0.8130  0.8136
# 3       0.8871  0.9706  0.9302  0.9091  0.9195  0.7304  0.7310
# 4       0.8387  0.9095  0.9286  0.8478  0.8864  0.6106  0.6181
# Mean    0.8742  0.9513  0.9299  0.8936  0.9111  0.6966  0.6996
# Std     0.0373  0.0276  0.0147  0.0405  0.0254  0.0944  0.0925

# %%
pred_loras_model6 = predict_model(op_loras_model6);
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8657  0.9293  0.9022  0.9022  0.9022
#
#     Kappa     MCC
# 0  0.6879  0.6879
